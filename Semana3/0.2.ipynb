# %%
# !pip install wget
import numpy as np
import matplotlib.pyplot as plt
import os.path as path
import wget

# %%
#a) Descargar los datos
def LoadFiles(file,url):
    if not path.exists(file):
        Path_ = wget.download(url,file)
        print('File loaded')
    else:
        Path_ = file
        
    return Path_

# %%
url = "https://raw.githubusercontent.com/asegura4488/Database/main/MetodosComputacionalesReforma/EnergiaPotencialGas2D.txt"
file = "Datos.dat"

# %%
datos = LoadFiles(file,url)

print (datos[:,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-dad3f75dfec7> in <module>
#       1 datos = LoadFiles(file,url)
#       2
# ----> 3 print (datos[:,1])
#
# TypeError: string indices must be integers

# %%
#b) Quitar el valor medio de la energía potencial

t = datos [:,0]

mean = np.mean(datos[:,1])
Ep = datos[:,1] - mean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ffd912bf9d5b> in <module>
#       1 #b) Quitar el valor medio de la energía potencial
#       2
# ----> 3 t = datos [:,0]
#       4
#       5 mean = np.mean(datos[:,1])
#
# TypeError: string indices must be integers

# %%
#c) Encontrar la fft

fft = np.fft.fft(Ep)
Npoints = len(Ep)
print(fft)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b2a1c5dde816> in <module>
#       1 #c) Encontrar la fft
#       2
# ----> 3 fft = np.fft.fft(Ep)
#       4 Npoints = len(Ep)
#       5 print(fft)
#
# NameError: name 'Ep' is not defined

# %%
#d) fftfreq

Frequencies = np.fft.fftfreq(Npoints,1)
print(Frequencies)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-54f571374d2c> in <module>
#       1 #d) fftfreq
#       2
# ----> 3 Frequencies = np.fft.fftfreq(Npoints,1)
#       4 print(Frequencies)
#
# NameError: name 'Npoints' is not defined

# %%
#e) Encontrar Tao

ffta = np.abs(fft)

mask2 = Frequencies < 0 
fft[mask2] = 0

NewFreq = np.arange(len(fft))

i = np.argmax(ffta)
FreqMax = Frequencies[i]
print(Frequencies[i])

Tao = 1/(Frequencies[i])
print (T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8278aa7fd189> in <module>
#       1 #e) Encontrar Tao
#       2
# ----> 3 ffta = np.abs(fft)
#       4
#       5 mask2 = Frequencies < 0
#
# NameError: name 'fft' is not defined

# %%
#f) Hacer el gráfico

F = np.cos((1/Tao)*t)

plt.figure()
plt.plot(t,Ep, linestyle='-',label='Serie Original')
plt.plot(t,F, linestyle='--', label='Fundamental', color='r')
plt.legend()
plt.xlabel("E[J]")
plt.ylabel("t[s]")
plt.show()
plt.savefig('TeimpoLibre.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-30ed1c47fbf7> in <module>
#       1 #f) Hacer el gráfico
#       2
# ----> 3 F = np.cos((1/Tao)*t)
#       4
#       5 plt.figure()
#
# NameError: name 'Tao' is not defined
